# %% [markdown]
# <a href="https://colab.research.google.com/github/polaabhiram/ML/blob/main/ML_Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Week-2 IRIS Dataset

# %% [markdown]
# 1.Write a Python program to load the iris data from a given csv file into a dataframe and
# print the shape of the data, type of the data and first 3 rows.

# %%
import pandas as pd

iris=pd.read_csv("/Iris.csv")

print("Shape:")
print(iris.shape)
print()
print("Data types")
print(iris.dtypes)
print()
print()
print("First 3 rows")
iris.drop(columns="Id").head(3)
# Out:
# Shape:
# (150, 6)
#
# Data types
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
#
# First 3 rows
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# 2.Write a Python program using Scikit-learn to print the keys, number of rows-columns,
# feature names and the description of the Iris data.

# %%
from sklearn import datasets

iris=datasets.load_iris()
print(iris.data.shape)
print(iris.feature_names)
print(iris.keys())
print()
iris.DESCR
# Out:
# (150, 4)
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# ...

# %% [markdown]
# 3.Write a Python program to get the number of observations, missing values and nan values

# %%
iris=pd.read_csv("/Iris.csv")

iris=iris.drop(columns="Id")
#no of observations
obs=iris['PetalLengthCm'].count()
print("Total no of observations:",obs)
print('\n',iris.groupby('Species').count())

#Missing values
print("\nNull Values:",iris.isnull().sum())
# Out:
# Total no of observations: 150
#
#                   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa                 50            50             50            50
# Iris-versicolor             50            50             50            50
# Iris-virginica              50            50             50            50
#
# Null Values: SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# 4.Write a Python program to view basic statistical details like percentile, mean, std etc.
# of iris data.

# %%
print('Mean',iris.groupby('Species').mean())
print('\nSTD',iris.groupby('Species').std())
print('\nMedian',iris.groupby('Species').median())
print('\nPercentile',iris.groupby('Species').quantile())
# Out:
# Mean                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026
#
# STD                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa           0.352490      0.381024       0.173511      0.107210
# Iris-versicolor       0.516171      0.313798       0.469911      0.197753
# Iris-virginica        0.635880      0.322497       0.551895      0.274650
#
# Median                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa                5.0           3.4           1.50           0.2
# Iris-versicolor            5.9           2.8           4.35           1.3
# Iris-virginica             6.5           3.0           5.55           2.0
#
# ...

# %% [markdown]
# 5.Write a Python program to access first four cells from a given Dataframe using the
# index and column labels. Call iris.csv to create the Dataframe.

# %%
iris[0:4]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
