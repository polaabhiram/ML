# %% [markdown]
# <a href="https://colab.research.google.com/github/polaabhiram/ML/blob/main/ML_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Week-2 IRIS Dataset

# %% [markdown]
# 1.Write a Python program to load the iris data from a given csv file into a dataframe and
# print the shape of the data, type of the data and first 3 rows.

# %%
import pandas as pd

iris=pd.read_csv("/content/Iris.csv")

print("Shape:")
print(iris.shape)
print()
print("Data types")
print(iris.dtypes)
print()
print()
print("First 3 rows")
iris.drop(columns="Id").head(3)
# Out:
# Shape:
# (150, 6)
#
# Data types
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
#
# First 3 rows
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# 2.Write a Python program using Scikit-learn to print the keys, number of rows-columns,
# feature names and the description of the Iris data.

# %%
from sklearn import datasets

iris=datasets.load_iris()
iris.data.shape
iris.feature_names
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
